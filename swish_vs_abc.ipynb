# %%
import pandas as pd

# %%
swish_loc = '/mnt/c/Users/jacobma1/Downloads/D1D_abc_feed_output.csv'
abc_loc = '/mnt/c/Users/jacobma1/Downloads/D1D_swish_feed_output.csv'

# %%
pd.read_csv(swish_loc)
# Out:
#         entity  feed_value                                            details  \
# 0   LAT402_PM2    0.061029  PROCESS=1278,ABC_FLAG_IDS=[1237671],OPERATIONS...
# 1       NST402    0.092111  PROCESS=1278,ABC_FLAG_IDS=[1237979],OPERATIONS...
# 2       TBF441    0.159328  PROCESS=1278,ABC_FLAG_IDS=[1237980],OPERATIONS...
# 3   PGX404_PM1    0.141622  PROCESS=1278,ABC_FLAG_IDS=[1238197],OPERATIONS...
# 4       EPF591    0.025168  PROCESS=1278,ABC_FLAG_IDS=[1248642],OPERATIONS...
# ..         ...         ...                                                ...
# 83  APT440_PM2    0.254270  PROCESS=1278,ABC_FLAG_IDS=[1281902],OPERATIONS...
# 84  APT440_PM3    0.185177  PROCESS=1278,ABC_FLAG_IDS=[1281903],OPERATIONS...
# 85  APT440_PM1    0.204634  PROCESS=1278,ABC_FLAG_IDS=[1281904],OPERATIONS...
# 86  GTA404_PM5    0.175589  PROCESS=1278,ABC_FLAG_IDS=[1281905],OPERATIONS...
# 87      CVD417    0.390605  PROCESS=1278,ABC_FLAG_IDS=[1281906],OPERATIONS...
#
#        data_last_update  fab
# ...

# %%
pd.read_csv(abc_loc)
# Out:
#          entity  feed_value  \
# 0        GTA453    0.656317
# 1        VFN430    0.534942
# 2        NST550    0.776802
# 3        KST420    0.999513
# 4        NST438    0.668805
# 5        KCD416    0.531329
# 6        JGR402    0.619792
# 7        SPA432    0.919345
# 8     DVD01_PM2    0.984687
# 9        EPF531    0.678500
# 10       LEO431    0.758623
# 11       NST448    0.997748
# 12       KST498    0.994258
# 13       KCD412    0.999994
# 14   APT438_PM3    0.535245
# 15       APT402    0.561103
# 16       APT401    0.997402
# 17   PAT524_PM1    0.899167
# 18       SAJ443    1.000000
# 19       DRT422    0.858923
# 20       CDT448    0.947032
# 21       FOX428    0.993602
# 22  ABV424_DCM1    0.915279
# 23       NST412    0.986337
# 24       OMG505    0.977704
# 25       SAF533    0.999778
# 26       NST510    0.692985
# 27   APT401_PM1    0.565242
# 28   GTT476_PM1    0.753253
# 29  CDT488_DCM1    0.561233
# 30       TBE406    0.870863
# 31       FOX406    0.979494
# ...

# %%
#Read the csv file and save it to a variable
swish = pd.read_csv(swish_loc) 
abc = pd.read_csv(abc_loc)

# %%
pd.to_datetime(swish['data_last_update'])
# Out:
# 0    2025-08-04 12:09:22
# 1    2025-08-07 20:44:02
# 2    2025-08-07 20:18:32
# 3    2025-08-07 16:51:46
# 4    2025-08-06 10:33:29
#              ...
# 83   2025-08-04 19:53:17
# 84   2025-08-04 19:53:17
# 85   2025-08-04 19:53:17
# 86   2025-08-07 01:06:09
# 87   2025-08-05 12:14:20
# Name: data_last_update, Length: 88, dtype: datetime64[ns]

# %%
pd.to_datetime(swish['data_last_update']).dt

# %%
pd.to_datetime(swish['data_last_update']).dt.strftime('%m/%d/%Y')
# Out:
# 0     08/04/2025
# 1     08/07/2025
# 2     08/07/2025
# 3     08/07/2025
# 4     08/06/2025
#          ...
# 83    08/04/2025
# 84    08/04/2025
# 85    08/04/2025
# 86    08/07/2025
# 87    08/05/2025
# Name: data_last_update, Length: 88, dtype: object

# %%
pd.to_datetime(abc['data_last_update']).dt.strftime('%m/%d/%Y')
# Out:
# 0     08/08/2025
# 1     08/08/2025
# 2     08/08/2025
# 3     08/08/2025
# 4     08/08/2025
# 5     08/08/2025
# 6     08/08/2025
# 7     08/08/2025
# 8     08/08/2025
# 9     08/08/2025
# 10    08/08/2025
# 11    08/08/2025
# 12    08/08/2025
# 13    08/08/2025
# 14    08/08/2025
# 15    08/08/2025
# 16    08/08/2025
# 17    08/08/2025
# 18    08/08/2025
# 19    08/08/2025
# 20    08/08/2025
# 21    08/08/2025
# 22    08/08/2025
# 23    08/08/2025
# 24    08/08/2025
# 25    08/08/2025
# 26    08/08/2025
# 27    08/08/2025
# 28    08/08/2025
# 29    08/08/2025
# 30    08/08/2025
# 31    08/08/2025
# 32    08/08/2025
# 33    08/08/2025
# 34    08/08/2025
# 35    08/08/2025
# 36    08/08/2025
# 37    08/08/2025
# 38    08/08/2025
# 39    08/08/2025
# 40    08/08/2025
# 41    08/08/2025
# 42    08/08/2025
# 43    08/08/2025
# 44    08/08/2025
# 45    08/08/2025
# 46    08/08/2025
# 47    08/08/2025
# 48    08/08/2025
# 49    08/08/2025
# 50    08/08/2025
# 51    08/08/2025
# ...

# %%
swish['data_last_update'] = pd.to_datetime(swish['data_last_update']).dt.strftime('%m/%d/%Y')
abc['data_last_update'] = pd.to_datetime(abc['data_last_update']).dt.strftime('%m/%d/%Y')

# %%
swish.head()
# Out:
#        entity  feed_value                                            details  \
# 0  LAT402_PM2    0.061029  PROCESS=1278,ABC_FLAG_IDS=[1237671],OPERATIONS...
# 1      NST402    0.092111  PROCESS=1278,ABC_FLAG_IDS=[1237979],OPERATIONS...
# 2      TBF441    0.159328  PROCESS=1278,ABC_FLAG_IDS=[1237980],OPERATIONS...
# 3  PGX404_PM1    0.141622  PROCESS=1278,ABC_FLAG_IDS=[1238197],OPERATIONS...
# 4      EPF591    0.025168  PROCESS=1278,ABC_FLAG_IDS=[1248642],OPERATIONS...
#
#   data_last_update  fab
# 0       08/04/2025  D1D
# 1       08/07/2025  D1D
# 2       08/07/2025  D1D
# 3       08/07/2025  D1D
# 4       08/06/2025  D1D

# %%
abc.head()
# Out:
#    entity  feed_value                                            details  \
# 0  GTA453    0.656317  DEVICE=*,LAYER=8BM5FC_FTL_DENSE,OPERATION=2349...
# 1  VFN430    0.534942  DEVICE=*,LAYER=8ZRO_FTL_PREGOOP,OPERATION=2022...
# 2  NST550    0.776802  DEVICE=*,LAYER=8DVDN_MG,OPERATION=255974,ABC_F...
# 3  KST420    0.999513  DEVICE=*,LAYER=8DVDN_MG,OPERATION=226446,ABC_F...
# 4  NST438    0.668805  DEVICE=*,LAYER=8DVDN_MG,OPERATION=188660,ABC_F...
#
#   data_last_update  fab
# 0       08/08/2025  D1D
# 1       08/08/2025  D1D
# 2       08/08/2025  D1D
# 3       08/08/2025  D1D
# 4       08/08/2025  D1D

# %% [markdown]
# # Finding matching entities

# %%
swish['entity'].value_counts()
# Out:
# entity
# LAT402_PM2    1
# NST402        1
# TBF441        1
# PGX404_PM1    1
# EPF591        1
#              ..
# APT440_PM2    1
# APT440_PM3    1
# APT440_PM1    1
# GTA404_PM5    1
# CVD417        1
# Name: count, Length: 88, dtype: int64

# %%
abc['entity'].value_counts()
# Out:
# entity
# GTA453         1
# VFN430         1
# NST550         1
# KST420         1
# NST438         1
# KCD416         1
# JGR402         1
# SPA432         1
# DVD01_PM2      1
# EPF531         1
# LEO431         1
# NST448         1
# KST498         1
# KCD412         1
# APT438_PM3     1
# APT402         1
# APT401         1
# PAT524_PM1     1
# SAJ443         1
# DRT422         1
# CDT448         1
# FOX428         1
# ABV424_DCM1    1
# NST412         1
# OMG505         1
# SAF533         1
# NST510         1
# APT401_PM1     1
# GTT476_PM1     1
# CDT488_DCM1    1
# TBE406         1
# FOX406         1
# FOX408         1
# ALE436         1
# FTL402         1
# OMG504         1
# SAF532         1
# PAT524_PM3     1
# KCD406         1
# KCD408         1
# DVD410_PM2     1
# NCD438         1
# PLI548         1
# PGX412_PM2     1
# DRT402         1
# SPK412         1
# NCD406         1
# PGX402         1
# FTL414         1
# BPQ418         1
# GTT448_PM5     1
# APT440         1
# ...

# %%
set(abc['entity']).intersection(set(swish['entity']))
# Out:
# {'ABV424_DCM1',
#  'ALE436',
#  'APT401',
#  'APT401_PM1',
#  'APT402',
#  'APT438_PM3',
#  'APT440',
#  'APT440_PM1',
#  'APT440_PM2',
#  'APT440_PM3',
#  'BPQ418',
#  'CDT448',
#  'CDT488_DCM1',
#  'CVD417',
#  'DRT422',
#  'DVD01_PM2',
#  'DVD410_PM2',
#  'EPF531',
#  'FOX406',
#  'FOX408',
#  'FOX428',
#  'FTL402',
#  'FTL414',
#  'GTA404_PM5',
#  'GTT448_PM5',
#  'GTT476_PM1',
#  'GTT588_PM2',
#  'JGR402',
#  'KCD406',
#  'KCD408',
#  'KCD412',
#  'KCD416',
#  'LEO431',
#  'NCD406',
#  'NCD438',
#  'NST412',
#  'NST448',
#  'NST510',
#  'OMG504',
#  'OMG505',
#  'PAT524_PM3',
#  'PGX402',
#  'PGX412_PM2',
#  'PLI548',
#  'SAF532',
#  'SAF533',
#  'SAJ443',
#  'SPA432',
#  'SPK412',
#  'TBE406'}

# %%
set(swish['entity']).intersection(set(abc['entity']))
# Out:
# {'ABV424_DCM1',
#  'ALE436',
#  'APT401',
#  'APT401_PM1',
#  'APT402',
#  'APT438_PM3',
#  'APT440',
#  'APT440_PM1',
#  'APT440_PM2',
#  'APT440_PM3',
#  'BPQ418',
#  'CDT448',
#  'CDT488_DCM1',
#  'CVD417',
#  'DRT422',
#  'DVD01_PM2',
#  'DVD410_PM2',
#  'EPF531',
#  'FOX406',
#  'FOX408',
#  'FOX428',
#  'FTL402',
#  'FTL414',
#  'GTA404_PM5',
#  'GTT448_PM5',
#  'GTT476_PM1',
#  'GTT588_PM2',
#  'JGR402',
#  'KCD406',
#  'KCD408',
#  'KCD412',
#  'KCD416',
#  'LEO431',
#  'NCD406',
#  'NCD438',
#  'NST412',
#  'NST448',
#  'NST510',
#  'OMG504',
#  'OMG505',
#  'PAT524_PM3',
#  'PGX402',
#  'PGX412_PM2',
#  'PLI548',
#  'SAF532',
#  'SAF533',
#  'SAJ443',
#  'SPA432',
#  'SPK412',
#  'TBE406'}

# %%
unique_swish_entities = swish['entity'].unique()
unique_abc_entities = abc['entity'].unique()
matching_entities = set(swish['entity']).intersection(set(abc['entity']))

print(f"""Number of unique entities in SWISH: {len(unique_swish_entities)}
      Number of unique entities in ABC: {len(unique_abc_entities)}
      Number of matching entities: {len(matching_entities)}""")
# Out:
# Number of unique entities in SWISH: 88
#       Number of unique entities in ABC: 58
#       Number of matching entities: 50

# %%
swish['entity']
# Out:
# 0     LAT402_PM2
# 1         NST402
# 2         TBF441
# 3     PGX404_PM1
# 4         EPF591
#          ...
# 83    APT440_PM2
# 84    APT440_PM3
# 85    APT440_PM1
# 86    GTA404_PM5
# 87        CVD417
# Name: entity, Length: 88, dtype: object

# %%
matching_entities
# Out:
# {'ABV424_DCM1',
#  'ALE436',
#  'APT401',
#  'APT401_PM1',
#  'APT402',
#  'APT438_PM3',
#  'APT440',
#  'APT440_PM1',
#  'APT440_PM2',
#  'APT440_PM3',
#  'BPQ418',
#  'CDT448',
#  'CDT488_DCM1',
#  'CVD417',
#  'DRT422',
#  'DVD01_PM2',
#  'DVD410_PM2',
#  'EPF531',
#  'FOX406',
#  'FOX408',
#  'FOX428',
#  'FTL402',
#  'FTL414',
#  'GTA404_PM5',
#  'GTT448_PM5',
#  'GTT476_PM1',
#  'GTT588_PM2',
#  'JGR402',
#  'KCD406',
#  'KCD408',
#  'KCD412',
#  'KCD416',
#  'LEO431',
#  'NCD406',
#  'NCD438',
#  'NST412',
#  'NST448',
#  'NST510',
#  'OMG504',
#  'OMG505',
#  'PAT524_PM3',
#  'PGX402',
#  'PGX412_PM2',
#  'PLI548',
#  'SAF532',
#  'SAF533',
#  'SAJ443',
#  'SPA432',
#  'SPK412',
#  'TBE406'}

# %%
swish['entity'].isin(matching_entities)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 83     True
# 84     True
# 85     True
# 86     True
# 87     True
# Name: entity, Length: 88, dtype: bool

# %%
swish[swish['entity'].isin(matching_entities)]
# Out:
#          entity  feed_value  \
# 17       PLI548    0.796795
# 29       APT402    0.246708
# 40       KCD416    0.744369
# 41       JGR402    0.793135
# 42       SPA432    0.886044
# 43    DVD01_PM2    0.255749
# 44       EPF531    0.234640
# 45       LEO431    0.213549
# 46       NST448    0.478271
# 47       KCD412    0.490074
# 48   APT438_PM3    0.336871
# 49       APT401    0.334222
# 50       SAJ443    0.750111
# 51       DRT422    0.542788
# 52       CDT448    0.542788
# 53       FOX428    0.253004
# 54  ABV424_DCM1    0.689385
# 55       NST412    0.799450
# 56       OMG505    0.805175
# 57       SAF533    0.793921
# 58       NST510    0.228752
# 59   APT401_PM1    0.475122
# 60   GTT476_PM1    0.317809
# 61  CDT488_DCM1    0.471916
# 62       TBE406    0.459195
# 63       FOX406    0.467007
# 64       FOX408    0.209424
# 65       ALE436    0.227334
# 66       FTL402    0.293627
# 67       OMG504    0.423904
# 68       SAF532    0.321054
# 69   PAT524_PM3    0.770876
# ...

# %%
swish_matches = swish[swish['entity'].isin(matching_entities)]
swish_matches.head()
# Out:
#     entity  feed_value                                            details  \
# 17  PLI548    0.796795  PROCESS=1278,ABC_FLAG_IDS=[1262864 1281825 128...
# 29  APT402    0.246708  PROCESS=1278,ABC_FLAG_IDS=[1276560 1281790 128...
# 40  KCD416    0.744369  PROCESS=1278,ABC_FLAG_IDS=[1281763 1281766 128...
# 41  JGR402    0.793135  PROCESS=1278,ABC_FLAG_IDS=[1281764 1281767 128...
# 42  SPA432    0.886044  PROCESS=1278,ABC_FLAG_IDS=[1281765 1281768 128...
#
#    data_last_update  fab
# 17       08/07/2025  D1D
# 29       08/07/2025  D1D
# 40       08/08/2025  D1D
# 41       08/08/2025  D1D
# 42       08/08/2025  D1D

# %%
abc[abc['entity'].isin(matching_entities)]
# Out:
#          entity  feed_value  \
# 5        KCD416    0.531329
# 6        JGR402    0.619792
# 7        SPA432    0.919345
# 8     DVD01_PM2    0.984687
# 9        EPF531    0.678500
# 10       LEO431    0.758623
# 11       NST448    0.997748
# 13       KCD412    0.999994
# 14   APT438_PM3    0.535245
# 15       APT402    0.561103
# 16       APT401    0.997402
# 18       SAJ443    1.000000
# 19       DRT422    0.858923
# 20       CDT448    0.947032
# 21       FOX428    0.993602
# 22  ABV424_DCM1    0.915279
# 23       NST412    0.986337
# 24       OMG505    0.977704
# 25       SAF533    0.999778
# 26       NST510    0.692985
# 27   APT401_PM1    0.565242
# 28   GTT476_PM1    0.753253
# 29  CDT488_DCM1    0.561233
# 30       TBE406    0.870863
# 31       FOX406    0.979494
# 32       FOX408    0.811398
# 33       ALE436    0.574977
# 34       FTL402    0.999995
# 35       OMG504    0.888045
# 36       SAF532    0.855995
# 37   PAT524_PM3    0.638518
# 38       KCD406    0.997810
# ...

# %%
abc_matches = abc[abc['entity'].isin(matching_entities)]
abc_matches.head()
# Out:
#       entity  feed_value                                            details  \
# 5     KCD416    0.531329  DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=25327...
# 6     JGR402    0.619792  DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=20110...
# 7     SPA432    0.919345  DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=24332...
# 8  DVD01_PM2    0.984687  DEVICE=*,LAYER=8TRM_FTL,OPERATION=258018,ABC_F...
# 9     EPF531    0.678500  DEVICE=*,LAYER=8TRM_FTL,OPERATION=261415,ABC_F...
#
#   data_last_update  fab
# 5       08/08/2025  D1D
# 6       08/08/2025  D1D
# 7       08/08/2025  D1D
# 8       08/08/2025  D1D
# 9       08/08/2025  D1D

# %%
swish_matches.head()
# Out:
#     entity  feed_value                                            details  \
# 17  PLI548    0.796795  PROCESS=1278,ABC_FLAG_IDS=[1262864 1281825 128...
# 29  APT402    0.246708  PROCESS=1278,ABC_FLAG_IDS=[1276560 1281790 128...
# 40  KCD416    0.744369  PROCESS=1278,ABC_FLAG_IDS=[1281763 1281766 128...
# 41  JGR402    0.793135  PROCESS=1278,ABC_FLAG_IDS=[1281764 1281767 128...
# 42  SPA432    0.886044  PROCESS=1278,ABC_FLAG_IDS=[1281765 1281768 128...
#
#    data_last_update  fab
# 17       08/07/2025  D1D
# 29       08/07/2025  D1D
# 40       08/08/2025  D1D
# 41       08/08/2025  D1D
# 42       08/08/2025  D1D

# %%
abc_matches.head()
# Out:
#       entity  feed_value                                            details  \
# 5     KCD416    0.531329  DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=25327...
# 6     JGR402    0.619792  DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=20110...
# 7     SPA432    0.919345  DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=24332...
# 8  DVD01_PM2    0.984687  DEVICE=*,LAYER=8TRM_FTL,OPERATION=258018,ABC_F...
# 9     EPF531    0.678500  DEVICE=*,LAYER=8TRM_FTL,OPERATION=261415,ABC_F...
#
#   data_last_update  fab
# 5       08/08/2025  D1D
# 6       08/08/2025  D1D
# 7       08/08/2025  D1D
# 8       08/08/2025  D1D
# 9       08/08/2025  D1D

# %% [markdown]
# # Only looking for date listed as 08/08/2025

# %%
swish_matches[swish_matches['data_last_update'] == '08/08/2025']
# Out:
#          entity  feed_value  \
# 40       KCD416    0.744369
# 41       JGR402    0.793135
# 42       SPA432    0.886044
# 51       DRT422    0.542788
# 52       CDT448    0.542788
# 53       FOX428    0.253004
# 54  ABV424_DCM1    0.689385
# 55       NST412    0.799450
# 56       OMG505    0.805175
# 57       SAF533    0.793921
# 58       NST510    0.228752
# 60   GTT476_PM1    0.317809
# 69   PAT524_PM3    0.770876
# 70       KCD406    0.879793
# 71       KCD408    0.864834
# 72   DVD410_PM2    0.871110
# 73       NCD438    0.885322
# 75       SPK412    0.085379
# 76       NCD406    0.125119
# 77       PGX402    0.230223
# 78       FTL414    0.216919
# 80   GTT448_PM5    0.119654
#
#                                               details data_last_update  fab
# 40  PROCESS=1278,ABC_FLAG_IDS=[1281763 1281766 128...       08/08/2025  D1D
# 41  PROCESS=1278,ABC_FLAG_IDS=[1281764 1281767 128...       08/08/2025  D1D
# ...

# %%
#Only looking for date listed as 08/08/2025
swish_filtered = swish_matches[swish_matches['data_last_update'] == '08/08/2025']
swish_filtered.head()
# Out:
#     entity  feed_value                                            details  \
# 40  KCD416    0.744369  PROCESS=1278,ABC_FLAG_IDS=[1281763 1281766 128...
# 41  JGR402    0.793135  PROCESS=1278,ABC_FLAG_IDS=[1281764 1281767 128...
# 42  SPA432    0.886044  PROCESS=1278,ABC_FLAG_IDS=[1281765 1281768 128...
# 51  DRT422    0.542788  PROCESS=1278,ABC_FLAG_IDS=[1281798],OPERATIONS...
# 52  CDT448    0.542788  PROCESS=1278,ABC_FLAG_IDS=[1281799],OPERATIONS...
#
#    data_last_update  fab
# 40       08/08/2025  D1D
# 41       08/08/2025  D1D
# 42       08/08/2025  D1D
# 51       08/08/2025  D1D
# 52       08/08/2025  D1D

# %%
#Only looking for abc data listed as 08/08/2025
abc_filtered = abc_matches[abc_matches['data_last_update'] == '08/08/2025']
abc_filtered.head()
# Out:
#       entity  feed_value                                            details  \
# 5     KCD416    0.531329  DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=25327...
# 6     JGR402    0.619792  DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=20110...
# 7     SPA432    0.919345  DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=24332...
# 8  DVD01_PM2    0.984687  DEVICE=*,LAYER=8TRM_FTL,OPERATION=258018,ABC_F...
# 9     EPF531    0.678500  DEVICE=*,LAYER=8TRM_FTL,OPERATION=261415,ABC_F...
#
#   data_last_update  fab
# 5       08/08/2025  D1D
# 6       08/08/2025  D1D
# 7       08/08/2025  D1D
# 8       08/08/2025  D1D
# 9       08/08/2025  D1D

# %%
set(swish_filtered['entity']).intersection(set(abc_filtered['entity']))
# Out:
# {'ABV424_DCM1',
#  'CDT448',
#  'DRT422',
#  'DVD410_PM2',
#  'FOX428',
#  'FTL414',
#  'GTT448_PM5',
#  'GTT476_PM1',
#  'JGR402',
#  'KCD406',
#  'KCD408',
#  'KCD416',
#  'NCD406',
#  'NCD438',
#  'NST412',
#  'NST510',
#  'OMG505',
#  'PAT524_PM3',
#  'PGX402',
#  'SAF533',
#  'SPA432',
#  'SPK412'}

# %%
swish_abc_filtered_0808_entity = set(swish_filtered['entity']).intersection(set(abc_filtered['entity']))

# %%
#All entities in swish_filtered are in 08/08/2025
swish_filtered['entity'].isin(swish_abc_filtered_0808_entity)
# Out:
# 40    True
# 41    True
# 42    True
# 51    True
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# 57    True
# 58    True
# 60    True
# 69    True
# 70    True
# 71    True
# 72    True
# 73    True
# 75    True
# 76    True
# 77    True
# 78    True
# 80    True
# Name: entity, dtype: bool

# %%
#Not all entities in abc_filtered are in 08/08/2025
abc_filtered['entity'].isin(swish_abc_filtered_0808_entity)
# Out:
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 13    False
# 14    False
# 15    False
# 16    False
# 18    False
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42    False
# 43    False
# 45     True
# 46     True
# 47     True
# 48     True
# 49    False
# 50     True
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# Name: entity, dtype: bool

# %%
type(swish_filtered)
# Out:
# pandas.core.frame.DataFrame

# %%
type(swish_abc_filtered_0808_entity)
# Out:
# set

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

#All entities in swish that are in 08/08/2025 and also in abc
swish_matching_0808 = swish_filtered[swish_filtered['entity'].isin(swish_abc_filtered_0808_entity)]
swish_matching_0808.head()
# Out:
#     entity  feed_value  \
# 40  KCD416    0.744369
# 41  JGR402    0.793135
# 42  SPA432    0.886044
# 51  DRT422    0.542788
# 52  CDT448    0.542788
#
#                                                                                       details  \
# 40  PROCESS=1278,ABC_FLAG_IDS=[1281763 1281766 1281772 1281794 1281843],OPERATIONS=['253279']
# 41  PROCESS=1278,ABC_FLAG_IDS=[1281764 1281767 1281773 1281795 1281844],OPERATIONS=['201102']
# 42  PROCESS=1278,ABC_FLAG_IDS=[1281765 1281768 1281774 1281796 1281845],OPERATIONS=['243323']
# 51                                  PROCESS=1278,ABC_FLAG_IDS=[1281798],OPERATIONS=['205090']
# 52                                  PROCESS=1278,ABC_FLAG_IDS=[1281799],OPERATIONS=['205074']
#
#    data_last_update  fab
# 40       08/08/2025  D1D
# 41       08/08/2025  D1D
# 42       08/08/2025  D1D
# 51       08/08/2025  D1D
# 52       08/08/2025  D1D

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
abc_matching_0808 = abc_filtered[abc_filtered['entity'].isin(swish_abc_filtered_0808_entity)]
abc_matching_0808.head()
# Out:
#     entity  feed_value  \
# 5   KCD416    0.531329
# 6   JGR402    0.619792
# 7   SPA432    0.919345
# 19  DRT422    0.858923
# 20  CDT448    0.947032
#
#                                                                 details  \
# 5   DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=253279,ABC_FLAG_ID=1281763
# 6   DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=201102,ABC_FLAG_ID=1281764
# 7   DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=243323,ABC_FLAG_ID=1281765
# 19         DEVICE=*,LAYER=8HNS_FTL,OPERATION=205090,ABC_FLAG_ID=1281798
# 20         DEVICE=*,LAYER=8HNS_FTL,OPERATION=205074,ABC_FLAG_ID=1281799
#
#    data_last_update  fab
# 5        08/08/2025  D1D
# 6        08/08/2025  D1D
# 7        08/08/2025  D1D
# 19       08/08/2025  D1D
# 20       08/08/2025  D1D

# %%
swish_matching_0808.rename(columns={
    'feed_value': 'feed_value_swish',
    'details': 'details_swish'
}).head()
# Out:
#     entity  feed_value_swish  \
# 40  KCD416          0.744369
# 41  JGR402          0.793135
# 42  SPA432          0.886044
# 51  DRT422          0.542788
# 52  CDT448          0.542788
#
#                                                                                 details_swish  \
# 40  PROCESS=1278,ABC_FLAG_IDS=[1281763 1281766 1281772 1281794 1281843],OPERATIONS=['253279']
# 41  PROCESS=1278,ABC_FLAG_IDS=[1281764 1281767 1281773 1281795 1281844],OPERATIONS=['201102']
# 42  PROCESS=1278,ABC_FLAG_IDS=[1281765 1281768 1281774 1281796 1281845],OPERATIONS=['243323']
# 51                                  PROCESS=1278,ABC_FLAG_IDS=[1281798],OPERATIONS=['205090']
# 52                                  PROCESS=1278,ABC_FLAG_IDS=[1281799],OPERATIONS=['205074']
#
#    data_last_update  fab
# 40       08/08/2025  D1D
# 41       08/08/2025  D1D
# 42       08/08/2025  D1D
# 51       08/08/2025  D1D
# 52       08/08/2025  D1D

# %%
abc_matching_0808.rename(columns={
    'feed_value': 'feed_value_abc',
    'details': 'details_abc'
}).head()
# Out:
#     entity  feed_value_abc  \
# 5   KCD416        0.531329
# 6   JGR402        0.619792
# 7   SPA432        0.919345
# 19  DRT422        0.858923
# 20  CDT448        0.947032
#
#                                                             details_abc  \
# 5   DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=253279,ABC_FLAG_ID=1281763
# 6   DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=201102,ABC_FLAG_ID=1281764
# 7   DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=243323,ABC_FLAG_ID=1281765
# 19         DEVICE=*,LAYER=8HNS_FTL,OPERATION=205090,ABC_FLAG_ID=1281798
# 20         DEVICE=*,LAYER=8HNS_FTL,OPERATION=205074,ABC_FLAG_ID=1281799
#
#    data_last_update  fab
# 5        08/08/2025  D1D
# 6        08/08/2025  D1D
# 7        08/08/2025  D1D
# 19       08/08/2025  D1D
# 20       08/08/2025  D1D

# %%
#Renaming columns before joining 
swish_matching_0808 = swish_matching_0808.rename(columns={
    'feed_value': 'feed_value_swish',
    'details': 'details_swish'
})
swish_matching_0808.head()
# Out:
#     entity  feed_value_swish  \
# 40  KCD416          0.744369
# 41  JGR402          0.793135
# 42  SPA432          0.886044
# 51  DRT422          0.542788
# 52  CDT448          0.542788
#
#                                                                                 details_swish  \
# 40  PROCESS=1278,ABC_FLAG_IDS=[1281763 1281766 1281772 1281794 1281843],OPERATIONS=['253279']
# 41  PROCESS=1278,ABC_FLAG_IDS=[1281764 1281767 1281773 1281795 1281844],OPERATIONS=['201102']
# 42  PROCESS=1278,ABC_FLAG_IDS=[1281765 1281768 1281774 1281796 1281845],OPERATIONS=['243323']
# 51                                  PROCESS=1278,ABC_FLAG_IDS=[1281798],OPERATIONS=['205090']
# 52                                  PROCESS=1278,ABC_FLAG_IDS=[1281799],OPERATIONS=['205074']
#
#    data_last_update  fab
# 40       08/08/2025  D1D
# 41       08/08/2025  D1D
# 42       08/08/2025  D1D
# 51       08/08/2025  D1D
# 52       08/08/2025  D1D

# %%
abc_matching_0808 = abc_matching_0808.rename(columns={
    'feed_value': 'feed_value_abc',
    'details': 'details_abc'
})
abc_matching_0808.head()
# Out:
#     entity  feed_value_abc  \
# 5   KCD416        0.531329
# 6   JGR402        0.619792
# 7   SPA432        0.919345
# 19  DRT422        0.858923
# 20  CDT448        0.947032
#
#                                                             details_abc  \
# 5   DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=253279,ABC_FLAG_ID=1281763
# 6   DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=201102,ABC_FLAG_ID=1281764
# 7   DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=243323,ABC_FLAG_ID=1281765
# 19         DEVICE=*,LAYER=8HNS_FTL,OPERATION=205090,ABC_FLAG_ID=1281798
# 20         DEVICE=*,LAYER=8HNS_FTL,OPERATION=205074,ABC_FLAG_ID=1281799
#
#    data_last_update  fab
# 5        08/08/2025  D1D
# 6        08/08/2025  D1D
# 7        08/08/2025  D1D
# 19       08/08/2025  D1D
# 20       08/08/2025  D1D

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None) 
swish_matching_0808.merge(
    abc_matching_0808,
    on=['entity', 'data_last_update', 'fab'],
    how='outer'
)
# Out:
#          entity  feed_value_swish  \
# 0   ABV424_DCM1          0.689385
# 1        CDT448          0.542788
# 2        DRT422          0.542788
# 3    DVD410_PM2          0.871110
# 4        FOX428          0.253004
# 5        FTL414          0.216919
# 6    GTT448_PM5          0.119654
# 7    GTT476_PM1          0.317809
# 8        JGR402          0.793135
# 9        KCD406          0.879793
# 10       KCD408          0.864834
# 11       KCD416          0.744369
# 12       NCD406          0.125119
# 13       NCD438          0.885322
# 14       NST412          0.799450
# 15       NST510          0.228752
# 16       OMG505          0.805175
# 17   PAT524_PM3          0.770876
# 18       PGX402          0.230223
# 19       SAF533          0.793921
# 20       SPA432          0.886044
# 21       SPK412          0.085379
#
#                                                                                 details_swish  \
# ...
