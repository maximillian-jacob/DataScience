# %%
import pandas as pd

# %%
swish_loc = '/mnt/c/Users/jacobma1/Downloads/D1D_abc_feed_output.csv'
abc_loc = '/mnt/c/Users/jacobma1/Downloads/D1D_swish_feed_output.csv'

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
swish = pd.read_csv(swish_loc)
swish.head()
# Out:
#        entity  feed_value  \
# 0  LAT402_PM2    0.061029
# 1      NST402    0.092111
# 2      TBF441    0.159328
# 3  PGX404_PM1    0.141622
# 4      EPF591    0.025168
#
#                                                                details  \
# 0     PROCESS=1278,ABC_FLAG_IDS=[1237671],OPERATIONS=['E_8ZRO_SI_LAT']
# 1  PROCESS=1278,ABC_FLAG_IDS=[1237979],OPERATIONS=['W_8PEPIBPRE_CLN2']
# 2  PROCESS=1278,ABC_FLAG_IDS=[1237980],OPERATIONS=['L_8PS2_SIARC_DEP']
# 3        PROCESS=1278,ABC_FLAG_IDS=[1238197],OPERATIONS=['E_8MGC_PCT']
# 4         PROCESS=1278,ABC_FLAG_IDS=[1248642],OPERATIONS=['T_8M5_EPN']
#
#       data_last_update  fab
# 0  2025-08-04 12:09:22  D1D
# 1  2025-08-07 20:44:02  D1D
# 2  2025-08-07 20:18:32  D1D
# 3  2025-08-07 16:51:46  D1D
# 4  2025-08-06 10:33:29  D1D

# %%
# import re 

# def extract_flag_id(details):
#     match = re.search(r'ABC_FLAG_IDS=\[(\d+)\]', details)
#     return match.group(1) if match else None 

import re 

def extract_flag_id(details):
    match = re.search(r'ABC_FLAG_IDS=\[(\d+)\]', details)
    return match.group(1) if match else None

# %%
# swish['details'].apply(extract_flag_id)
swish['details'].apply(extract_flag_id)
# Out:
# 0     1237671
# 1     1237979
# 2     1237980
# 3     1238197
# 4     1248642
#        ...
# 83    1281902
# 84    1281903
# 85    1281904
# 86    1281905
# 87    1281906
# Name: details, Length: 88, dtype: object

# %%
# #Adding flag_id to swish
# swish['FLAG_ID'] = swish['details'].apply(extract_flag_id)
# swish.head()

swish['FLAG_ID'] = swish['details'].apply(extract_flag_id)
swish.head()
# Out:
#        entity  feed_value  \
# 0  LAT402_PM2    0.061029
# 1      NST402    0.092111
# 2      TBF441    0.159328
# 3  PGX404_PM1    0.141622
# 4      EPF591    0.025168
#
#                                                                details  \
# 0     PROCESS=1278,ABC_FLAG_IDS=[1237671],OPERATIONS=['E_8ZRO_SI_LAT']
# 1  PROCESS=1278,ABC_FLAG_IDS=[1237979],OPERATIONS=['W_8PEPIBPRE_CLN2']
# 2  PROCESS=1278,ABC_FLAG_IDS=[1237980],OPERATIONS=['L_8PS2_SIARC_DEP']
# 3        PROCESS=1278,ABC_FLAG_IDS=[1238197],OPERATIONS=['E_8MGC_PCT']
# 4         PROCESS=1278,ABC_FLAG_IDS=[1248642],OPERATIONS=['T_8M5_EPN']
#
#       data_last_update  fab  FLAG_ID
# 0  2025-08-04 12:09:22  D1D  1237671
# 1  2025-08-07 20:44:02  D1D  1237979
# 2  2025-08-07 20:18:32  D1D  1237980
# 3  2025-08-07 16:51:46  D1D  1238197
# 4  2025-08-06 10:33:29  D1D  1248642

# %%
# #renaming some of the columns 
# swish = swish.rename(columns = {
#     'feed_value': 'feed_valu_swish',
#     'details': 'details_swish'
# })
# swish.head()

swish = swish.rename(columns={
    'feed_value': 'feed_value_swish',
    'details': 'details_swish',
    'data_last_update': 'data_last_update_swish'
})
swish.head()
# Out:
#        entity  feed_value_swish  \
# 0  LAT402_PM2          0.061029
# 1      NST402          0.092111
# 2      TBF441          0.159328
# 3  PGX404_PM1          0.141622
# 4      EPF591          0.025168
#
#                                                          details_swish  \
# 0     PROCESS=1278,ABC_FLAG_IDS=[1237671],OPERATIONS=['E_8ZRO_SI_LAT']
# 1  PROCESS=1278,ABC_FLAG_IDS=[1237979],OPERATIONS=['W_8PEPIBPRE_CLN2']
# 2  PROCESS=1278,ABC_FLAG_IDS=[1237980],OPERATIONS=['L_8PS2_SIARC_DEP']
# 3        PROCESS=1278,ABC_FLAG_IDS=[1238197],OPERATIONS=['E_8MGC_PCT']
# 4         PROCESS=1278,ABC_FLAG_IDS=[1248642],OPERATIONS=['T_8M5_EPN']
#
#   data_last_update_swish  fab  FLAG_ID
# 0    2025-08-04 12:09:22  D1D  1237671
# 1    2025-08-07 20:44:02  D1D  1237979
# 2    2025-08-07 20:18:32  D1D  1237980
# 3    2025-08-07 16:51:46  D1D  1238197
# 4    2025-08-06 10:33:29  D1D  1248642

# %%
# pd.set_option('display.max_colwidth', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# abc = pd.read_csv(abc_loc)
# abc.head()

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
abc = pd.read_csv(abc_loc)
abc.head()
# Out:
#    entity  feed_value  \
# 0  GTA453    0.656317
# 1  VFN430    0.534942
# 2  NST550    0.776802
# 3  KST420    0.999513
# 4  NST438    0.668805
#
#                                                                 details  \
# 0  DEVICE=*,LAYER=8BM5FC_FTL_DENSE,OPERATION=234906,ABC_FLAG_ID=1281638
# 1  DEVICE=*,LAYER=8ZRO_FTL_PREGOOP,OPERATION=202264,ABC_FLAG_ID=1281639
# 2          DEVICE=*,LAYER=8DVDN_MG,OPERATION=255974,ABC_FLAG_ID=1281654
# 3          DEVICE=*,LAYER=8DVDN_MG,OPERATION=226446,ABC_FLAG_ID=1281655
# 4          DEVICE=*,LAYER=8DVDN_MG,OPERATION=188660,ABC_FLAG_ID=1281656
#
#   data_last_update  fab
# 0       2025-08-08  D1D
# 1       2025-08-08  D1D
# 2       2025-08-08  D1D
# 3       2025-08-08  D1D
# 4       2025-08-08  D1D

# %%
# def extract_flag_id_abc(details):
#     match = re.search(r'ABC_FLAG_ID=(\d+)', details)
#     return match.group(1) if match else None 

def extract_flag_id_abc(details):
    match = re.search(r'ABC_FLAG_ID=(\d+)', details)
    return match.group(1) if match else None

# %%
# abc['details'].apply(extract_flag_id_abc)
abc['details'].apply(extract_flag_id_abc)
# Out:
# 0     1281638
# 1     1281639
# 2     1281654
# 3     1281655
# 4     1281656
# 5     1281763
# 6     1281764
# 7     1281765
# 8     1281769
# 9     1281770
# 10    1281771
# 11    1281912
# 12    1281785
# 13    1281788
# 14    1281789
# 15    1281790
# 16    1281791
# 17    1281792
# 18    1281907
# 19    1281798
# 20    1281799
# 21    1281800
# 22    1281801
# 23    1281802
# 24    1281803
# 25    1281804
# 26    1281809
# 27    1281810
# 28    1281811
# 29    1281812
# 30    1281813
# 31    1281814
# 32    1281815
# 33    1281816
# 34    1281817
# 35    1281818
# 36    1281819
# 37    1281820
# 38    1281821
# 39    1281822
# 40    1281823
# 41    1281824
# 42    1281825
# 43    1281826
# 44    1281827
# 45    1281836
# 46    1281837
# 47    1281838
# 48    1281839
# 49    1281840
# 50    1281868
# 51    1281869
# 52    1281901
# 53    1281902
# 54    1281903
# 55    1281904
# 56    1281905
# 57    1281906
# Name: details, dtype: object

# %%
# #Adding flag_id to abc
# abc['FLAG_ID'] = abc['details'].apply(extract_flag_id_abc)
# abc.head()

abc['FLAG_ID'] = abc['details'].apply(extract_flag_id_abc)
abc.head()
# Out:
#    entity  feed_value  \
# 0  GTA453    0.656317
# 1  VFN430    0.534942
# 2  NST550    0.776802
# 3  KST420    0.999513
# 4  NST438    0.668805
#
#                                                                 details  \
# 0  DEVICE=*,LAYER=8BM5FC_FTL_DENSE,OPERATION=234906,ABC_FLAG_ID=1281638
# 1  DEVICE=*,LAYER=8ZRO_FTL_PREGOOP,OPERATION=202264,ABC_FLAG_ID=1281639
# 2          DEVICE=*,LAYER=8DVDN_MG,OPERATION=255974,ABC_FLAG_ID=1281654
# 3          DEVICE=*,LAYER=8DVDN_MG,OPERATION=226446,ABC_FLAG_ID=1281655
# 4          DEVICE=*,LAYER=8DVDN_MG,OPERATION=188660,ABC_FLAG_ID=1281656
#
#   data_last_update  fab  FLAG_ID
# 0       2025-08-08  D1D  1281638
# 1       2025-08-08  D1D  1281639
# 2       2025-08-08  D1D  1281654
# 3       2025-08-08  D1D  1281655
# 4       2025-08-08  D1D  1281656

# %%
# abc.rename(columns= {
#     'feed_value': 'feed_value_abc',
#     'details': 'details_abc'
# })

abc.rename(columns = {
    'feed_value': 'feed_value_abc',
    'details': 'details_abc'
})
# Out:
#          entity  feed_value_abc  \
# 0        GTA453        0.656317
# 1        VFN430        0.534942
# 2        NST550        0.776802
# 3        KST420        0.999513
# 4        NST438        0.668805
# 5        KCD416        0.531329
# 6        JGR402        0.619792
# 7        SPA432        0.919345
# 8     DVD01_PM2        0.984687
# 9        EPF531        0.678500
# 10       LEO431        0.758623
# 11       NST448        0.997748
# 12       KST498        0.994258
# 13       KCD412        0.999994
# 14   APT438_PM3        0.535245
# 15       APT402        0.561103
# 16       APT401        0.997402
# 17   PAT524_PM1        0.899167
# 18       SAJ443        1.000000
# 19       DRT422        0.858923
# 20       CDT448        0.947032
# 21       FOX428        0.993602
# 22  ABV424_DCM1        0.915279
# 23       NST412        0.986337
# 24       OMG505        0.977704
# 25       SAF533        0.999778
# 26       NST510        0.692985
# 27   APT401_PM1        0.565242
# 28   GTT476_PM1        0.753253
# 29  CDT488_DCM1        0.561233
# 30       TBE406        0.870863
# 31       FOX406        0.979494
# 32       FOX408        0.811398
# 33       ALE436        0.574977
# 34       FTL402        0.999995
# 35       OMG504        0.888045
# 36       SAF532        0.855995
# 37   PAT524_PM3        0.638518
# 38       KCD406        0.997810
# 39       KCD408        0.798898
# 40   DVD410_PM2        0.980972
# 41       NCD438        0.996776
# 42       PLI548        0.975624
# 43   PGX412_PM2        0.556466
# 44       DRT402        0.679441
# 45       SPK412        0.978923
# 46       NCD406        0.989080
# 47       PGX402        0.994446
# 48       FTL414        0.999627
# 49       BPQ418        0.648215
# 50   GTT448_PM5        0.730354
# 51       APT440        0.919374
# 52   GTT588_PM2        0.679347
# 53   APT440_PM2        0.976454
# 54   APT440_PM3        0.939870
# 55   APT440_PM1        0.939870
# 56   GTA404_PM5        1.000000
# 57       CVD417        0.688425
#
#                                                              details_abc  \
# 0   DEVICE=*,LAYER=8BM5FC_FTL_DENSE,OPERATION=234906,ABC_FLAG_ID=1281638
# 1   DEVICE=*,LAYER=8ZRO_FTL_PREGOOP,OPERATION=202264,ABC_FLAG_ID=1281639
# 2           DEVICE=*,LAYER=8DVDN_MG,OPERATION=255974,ABC_FLAG_ID=1281654
# 3           DEVICE=*,LAYER=8DVDN_MG,OPERATION=226446,ABC_FLAG_ID=1281655
# 4           DEVICE=*,LAYER=8DVDN_MG,OPERATION=188660,ABC_FLAG_ID=1281656
# 5    DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=253279,ABC_FLAG_ID=1281763
# 6    DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=201102,ABC_FLAG_ID=1281764
# 7    DEVICE=*,LAYER=8PLYPSTOXHM_HVF,OPERATION=243323,ABC_FLAG_ID=1281765
# 8           DEVICE=*,LAYER=8TRM_FTL,OPERATION=258018,ABC_FLAG_ID=1281769
# 9           DEVICE=*,LAYER=8TRM_FTL,OPERATION=261415,ABC_FLAG_ID=1281770
# 10          DEVICE=*,LAYER=8TRM_FTL,OPERATION=243221,ABC_FLAG_ID=1281771
# 11       DEVICE=*,LAYER=8PROTON_FTL,OPERATION=194816,ABC_FLAG_ID=1281912
# 12       DEVICE=*,LAYER=8PROTON_FTL,OPERATION=210944,ABC_FLAG_ID=1281785
# 13       DEVICE=*,LAYER=8TLKPOL_FTL,OPERATION=261769,ABC_FLAG_ID=1281788
# 14       DEVICE=*,LAYER=8TLKPOL_FTL,OPERATION=258362,ABC_FLAG_ID=1281789
# 15       DEVICE=*,LAYER=8TLKPOL_FTL,OPERATION=265383,ABC_FLAG_ID=1281790
# 16       DEVICE=*,LAYER=8TLKPOL_FTL,OPERATION=242980,ABC_FLAG_ID=1281791
# 17       DEVICE=*,LAYER=8TLKPOL_FTL,OPERATION=265186,ABC_FLAG_ID=1281792
# 18          DEVICE=*,LAYER=8VCG_FTL,OPERATION=270604,ABC_FLAG_ID=1281907
# 19          DEVICE=*,LAYER=8HNS_FTL,OPERATION=205090,ABC_FLAG_ID=1281798
# 20          DEVICE=*,LAYER=8HNS_FTL,OPERATION=205074,ABC_FLAG_ID=1281799
# 21          DEVICE=*,LAYER=8HNS_FTL,OPERATION=205122,ABC_FLAG_ID=1281800
# 22          DEVICE=*,LAYER=8HNS_FTL,OPERATION=205632,ABC_FLAG_ID=1281801
# 23          DEVICE=*,LAYER=8HNS_FTL,OPERATION=225704,ABC_FLAG_ID=1281802
# 24          DEVICE=*,LAYER=8HNS_FTL,OPERATION=242933,ABC_FLAG_ID=1281803
# 25          DEVICE=*,LAYER=8HNS_FTL,OPERATION=242990,ABC_FLAG_ID=1281804
# 26       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=225401,ABC_FLAG_ID=1281809
# 27       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=225083,ABC_FLAG_ID=1281810
# 28       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=247751,ABC_FLAG_ID=1281811
# 29       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=226440,ABC_FLAG_ID=1281812
# 30       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=226792,ABC_FLAG_ID=1281813
# 31       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=225210,ABC_FLAG_ID=1281814
# 32       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=225210,ABC_FLAG_ID=1281815
# 33       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=258704,ABC_FLAG_ID=1281816
# 34       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=214155,ABC_FLAG_ID=1281817
# 35       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=242939,ABC_FLAG_ID=1281818
# 36       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=258365,ABC_FLAG_ID=1281819
# 37            DEVICE=*,LAYER=8PYREM,OPERATION=210952,ABC_FLAG_ID=1281820
# 38            DEVICE=*,LAYER=8PYREM,OPERATION=247702,ABC_FLAG_ID=1281821
# 39            DEVICE=*,LAYER=8PYREM,OPERATION=247701,ABC_FLAG_ID=1281822
# 40            DEVICE=*,LAYER=8PYREM,OPERATION=194483,ABC_FLAG_ID=1281823
# 41            DEVICE=*,LAYER=8PYREM,OPERATION=257349,ABC_FLAG_ID=1281824
# 42            DEVICE=*,LAYER=8ZROFC,OPERATION=179532,ABC_FLAG_ID=1281825
# 43       DEVICE=*,LAYER=8PCTPOL_FTL,OPERATION=235368,ABC_FLAG_ID=1281826
# 44      DEVICE=*,LAYER=8M5CP_PLANAR,OPERATION=173542,ABC_FLAG_ID=1281827
# 45     DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=207026,ABC_FLAG_ID=1281836
# 46     DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=254145,ABC_FLAG_ID=1281837
# 47     DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=251263,ABC_FLAG_ID=1281838
# 48     DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=214155,ABC_FLAG_ID=1281839
# 49     DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=143803,ABC_FLAG_ID=1281840
# 50       DEVICE=*,LAYER=8VCXPOL_FTL,OPERATION=245040,ABC_FLAG_ID=1281868
# 51       DEVICE=*,LAYER=8VCXPOL_FTL,OPERATION=254454,ABC_FLAG_ID=1281869
# 52          DEVICE=*,LAYER=8VCG_FTL,OPERATION=245041,ABC_FLAG_ID=1281901
# 53          DEVICE=*,LAYER=8VCG_FTL,OPERATION=240261,ABC_FLAG_ID=1281902
# 54          DEVICE=*,LAYER=8VCG_FTL,OPERATION=240261,ABC_FLAG_ID=1281903
# 55          DEVICE=*,LAYER=8VCG_FTL,OPERATION=240261,ABC_FLAG_ID=1281904
# 56          DEVICE=*,LAYER=8VCG_FTL,OPERATION=254617,ABC_FLAG_ID=1281905
# 57          DEVICE=*,LAYER=8VCG_FTL,OPERATION=212825,ABC_FLAG_ID=1281906
#
#    data_last_update  fab  FLAG_ID
# 0        2025-08-08  D1D  1281638
# 1        2025-08-08  D1D  1281639
# 2        2025-08-08  D1D  1281654
# 3        2025-08-08  D1D  1281655
# 4        2025-08-08  D1D  1281656
# 5        2025-08-08  D1D  1281763
# 6        2025-08-08  D1D  1281764
# 7        2025-08-08  D1D  1281765
# 8        2025-08-08  D1D  1281769
# 9        2025-08-08  D1D  1281770
# 10       2025-08-08  D1D  1281771
# 11       2025-08-08  D1D  1281912
# 12       2025-08-08  D1D  1281785
# 13       2025-08-08  D1D  1281788
# 14       2025-08-08  D1D  1281789
# 15       2025-08-08  D1D  1281790
# 16       2025-08-08  D1D  1281791
# 17       2025-08-08  D1D  1281792
# 18       2025-08-08  D1D  1281907
# 19       2025-08-08  D1D  1281798
# 20       2025-08-08  D1D  1281799
# 21       2025-08-08  D1D  1281800
# 22       2025-08-08  D1D  1281801
# 23       2025-08-08  D1D  1281802
# 24       2025-08-08  D1D  1281803
# 25       2025-08-08  D1D  1281804
# 26       2025-08-08  D1D  1281809
# 27       2025-08-08  D1D  1281810
# 28       2025-08-08  D1D  1281811
# 29       2025-08-08  D1D  1281812
# 30       2025-08-08  D1D  1281813
# 31       2025-08-08  D1D  1281814
# 32       2025-08-08  D1D  1281815
# 33       2025-08-08  D1D  1281816
# 34       2025-08-08  D1D  1281817
# 35       2025-08-08  D1D  1281818
# 36       2025-08-08  D1D  1281819
# 37       2025-08-08  D1D  1281820
# 38       2025-08-08  D1D  1281821
# 39       2025-08-08  D1D  1281822
# 40       2025-08-08  D1D  1281823
# 41       2025-08-08  D1D  1281824
# 42       2025-08-08  D1D  1281825
# 43       2025-08-08  D1D  1281826
# 44       2025-08-08  D1D  1281827
# 45       2025-08-08  D1D  1281836
# 46       2025-08-08  D1D  1281837
# 47       2025-08-08  D1D  1281838
# 48       2025-08-08  D1D  1281839
# 49       2025-08-08  D1D  1281840
# 50       2025-08-08  D1D  1281868
# 51       2025-08-08  D1D  1281869
# 52       2025-08-08  D1D  1281901
# 53       2025-08-08  D1D  1281902
# 54       2025-08-08  D1D  1281903
# 55       2025-08-08  D1D  1281904
# 56       2025-08-08  D1D  1281905
# 57       2025-08-08  D1D  1281906

# %%
# abc = abc.rename(columns={
#     'feed_value': 'feed_value_abc',
#     'details': 'details_abc'
# })
# abc.head()

abc = abc.rename( columns={
    'feed_value': 'feed_value_abc',
    'details': 'details_abc',
    'data_last_update': 'data_last_update_abc'
})
abc.head()
# Out:
#    entity  feed_value_abc  \
# 0  GTA453        0.656317
# 1  VFN430        0.534942
# 2  NST550        0.776802
# 3  KST420        0.999513
# 4  NST438        0.668805
#
#                                                             details_abc  \
# 0  DEVICE=*,LAYER=8BM5FC_FTL_DENSE,OPERATION=234906,ABC_FLAG_ID=1281638
# 1  DEVICE=*,LAYER=8ZRO_FTL_PREGOOP,OPERATION=202264,ABC_FLAG_ID=1281639
# 2          DEVICE=*,LAYER=8DVDN_MG,OPERATION=255974,ABC_FLAG_ID=1281654
# 3          DEVICE=*,LAYER=8DVDN_MG,OPERATION=226446,ABC_FLAG_ID=1281655
# 4          DEVICE=*,LAYER=8DVDN_MG,OPERATION=188660,ABC_FLAG_ID=1281656
#
#   data_last_update_abc  fab  FLAG_ID
# 0           2025-08-08  D1D  1281638
# 1           2025-08-08  D1D  1281639
# 2           2025-08-08  D1D  1281654
# 3           2025-08-08  D1D  1281655
# 4           2025-08-08  D1D  1281656

# %%
#abc has 58 observations
#swish has 88 observations
abc.shape, swish.shape
# Out:
# ((58, 6), (88, 6))

# %%
len(abc), len(swish)
# Out:
# (58, 88)

# %%
abc.nunique()
# Out:
# entity                  58
# feed_value_abc          57
# details_abc             58
# data_last_update_abc     1
# fab                      1
# FLAG_ID                 58
# dtype: int64

# %%
# ...existing code...
print(f"ABC flags {abc['entity'].nunique()} unique entities as potentially problematic.")
print(f"ABC flags {abc['FLAG_ID'].nunique()} unique FLAG_IDs.")
# Out:
# ABC flags 58 unique entities as potentially problematic.
# ABC flags 58 unique FLAG_IDs.

# %%
#Repeated flag_id. The same flag_id is associated to different entities.
#Need to understand the mechanism behind flag_id association. 
#What would be some scenarios tha lead to different entites have the same flag?
#I can make sense if multiple flag_id is assiged tot he same tool. I assume that means the tool is raising different flags on multiple occassion.
#However what would be the reason for the same flag_id to be associated with different entities?
swish.nunique()
# Out:
# entity                    88
# feed_value_swish          84
# details_swish             88
# data_last_update_swish    63
# fab                        1
# FLAG_ID                   71
# dtype: int64

# %%
print(f"SWISH flags {swish['entity'].nunique()} unique entities as potentially problematic.")
print(f"SWISH flags {swish['FLAG_ID'].nunique()} unique FLAG_IDs.")
# Out:
# SWISH flags 88 unique entities as potentially problematic.
# SWISH flags 71 unique FLAG_IDs.

# %% [markdown]
# # Converting the data_last_update to a format that will be recognizable by python as a date/time format.
#
# Standardizing the date format for both swish and abc

# %%
#Converting to date time and standardizing the date format
swish['data_last_update_swish'] = pd.to_datetime(swish['data_last_update_swish']).dt.strftime('%m/%d/%Y')
swish.head()
# Out:
#        entity  feed_value_swish  \
# 0  LAT402_PM2          0.061029
# 1      NST402          0.092111
# 2      TBF441          0.159328
# 3  PGX404_PM1          0.141622
# 4      EPF591          0.025168
#
#                                                          details_swish  \
# 0     PROCESS=1278,ABC_FLAG_IDS=[1237671],OPERATIONS=['E_8ZRO_SI_LAT']
# 1  PROCESS=1278,ABC_FLAG_IDS=[1237979],OPERATIONS=['W_8PEPIBPRE_CLN2']
# 2  PROCESS=1278,ABC_FLAG_IDS=[1237980],OPERATIONS=['L_8PS2_SIARC_DEP']
# 3        PROCESS=1278,ABC_FLAG_IDS=[1238197],OPERATIONS=['E_8MGC_PCT']
# 4         PROCESS=1278,ABC_FLAG_IDS=[1248642],OPERATIONS=['T_8M5_EPN']
#
#   data_last_update_swish  fab  FLAG_ID
# 0             08/04/2025  D1D  1237671
# 1             08/07/2025  D1D  1237979
# 2             08/07/2025  D1D  1237980
# 3             08/07/2025  D1D  1238197
# 4             08/06/2025  D1D  1248642

# %%
# swish.to_csv('swish.csv', index=False)

# %%
len(swish)
# Out:
# 88

# %%
swish['FLAG_ID'].value_counts()
# Out:
# FLAG_ID
# 1237671    1
# 1237979    1
# 1237980    1
# 1238197    1
# 1248642    1
#           ..
# 1281902    1
# 1281903    1
# 1281904    1
# 1281905    1
# 1281906    1
# Name: count, Length: 71, dtype: int64

# %%
# Find FLAG_IDs associated with multiple entities (tools)
flag_counts = swish.groupby('FLAG_ID')['entity'].nunique()
duplicate_flags = flag_counts[flag_counts > 1].index

# Show entities (tools) for each duplicate FLAG_ID
tools_per_flag = swish[swish['FLAG_ID'].isin(duplicate_flags)].groupby('FLAG_ID')['entity'].unique()
print(tools_per_flag)
# Out:
# Series([], Name: entity, dtype: object)

# %%
#Find FLAG_IDS asscociated with multiple entities
flag_counts = swish.groupby('FLAG_ID')['entity'].unique()

flag_counts[flag_counts > 1].index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 4
#       1 #Find FLAG_IDS asscociated with multiple entities
#       2 flag_counts = swish.groupby('FLAG_ID')['entity'].unique()
# ----> 4 flag_counts[flag_counts > 1].index
#
# File ~/defmet/datasci/.venv/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/defmet/datasci/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~/defmet/datasci/.venv/lib/python3.12/site-packages/pandas/core/series.py:6130, in Series._cmp_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6132 return self._construct_result(res_values, name=res_name)
#
# File ~/defmet/datasci/.venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/defmet/datasci/.venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
abc['data_last_update_abc'] = pd.to_datetime(abc['data_last_update_abc']).dt.strftime('%m/%d/%Y')
abc.head()
# Out:
#    entity  feed_value_abc  \
# 0  GTA453        0.656317
# 1  VFN430        0.534942
# 2  NST550        0.776802
# 3  KST420        0.999513
# 4  NST438        0.668805
#
#                                                             details_abc  \
# 0  DEVICE=*,LAYER=8BM5FC_FTL_DENSE,OPERATION=234906,ABC_FLAG_ID=1281638
# 1  DEVICE=*,LAYER=8ZRO_FTL_PREGOOP,OPERATION=202264,ABC_FLAG_ID=1281639
# 2          DEVICE=*,LAYER=8DVDN_MG,OPERATION=255974,ABC_FLAG_ID=1281654
# 3          DEVICE=*,LAYER=8DVDN_MG,OPERATION=226446,ABC_FLAG_ID=1281655
# 4          DEVICE=*,LAYER=8DVDN_MG,OPERATION=188660,ABC_FLAG_ID=1281656
#
#   data_last_update_abc  fab  FLAG_ID
# 0           08/08/2025  D1D  1281638
# 1           08/08/2025  D1D  1281639
# 2           08/08/2025  D1D  1281654
# 3           08/08/2025  D1D  1281655
# 4           08/08/2025  D1D  1281656

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

swish.merge(
    abc,
    on=['entity', 'fab', 'FLAG_ID'],
    how='outer'
)
# Out:
#           entity  feed_value_swish  \
# 0    ABV424_DCM1          0.689385
# 1         ALE436          0.227334
# 2     AME425_PM6          0.028050
# 3         APT401               NaN
# 4         APT401          0.334222
# ..           ...               ...
# 107       SPK412          0.085379
# 108       TAU446          0.109319
# 109       TBE406          0.459195
# 110       TBF441          0.159328
# 111       VFN430               NaN
#
#                                                            details_swish  \
# 0              PROCESS=1278,ABC_FLAG_IDS=[1281801],OPERATIONS=['205632']
# 1              PROCESS=1278,ABC_FLAG_IDS=[1281816],OPERATIONS=['258704']
# 2      PROCESS=1278,ABC_FLAG_IDS=[1252389],OPERATIONS=['E_8BM0_HM_ETCH']
# 3                                                                    NaN
# 4      PROCESS=1278,ABC_FLAG_IDS=[1281791 1281849],OPERATIONS=['242980']
# ..                                                                   ...
# 107            PROCESS=1278,ABC_FLAG_IDS=[1281836],OPERATIONS=['207026']
# 108         PROCESS=1278,ABC_FLAG_IDS=[1263738],OPERATIONS=['L_8V6_SED']
# 109            PROCESS=1278,ABC_FLAG_IDS=[1281813],OPERATIONS=['226792']
# 110  PROCESS=1278,ABC_FLAG_IDS=[1237980],OPERATIONS=['L_8PS2_SIARC_DEP']
# 111                                                                  NaN
#
#     data_last_update_swish  fab  FLAG_ID  feed_value_abc  \
# 0               08/08/2025  D1D  1281801        0.915279
# 1               08/07/2025  D1D  1281816        0.574977
# 2               08/05/2025  D1D  1252389             NaN
# 3                      NaN  D1D  1281791        0.997402
# 4               08/07/2025  D1D     None             NaN
# ..                     ...  ...      ...             ...
# 107             08/08/2025  D1D  1281836        0.978923
# 108             08/08/2025  D1D  1263738             NaN
# 109             08/05/2025  D1D  1281813        0.870863
# 110             08/07/2025  D1D  1237980             NaN
# 111                    NaN  D1D  1281639        0.534942
#
#                                                               details_abc  \
# 0            DEVICE=*,LAYER=8HNS_FTL,OPERATION=205632,ABC_FLAG_ID=1281801
# 1         DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=258704,ABC_FLAG_ID=1281816
# 2                                                                     NaN
# 3         DEVICE=*,LAYER=8TLKPOL_FTL,OPERATION=242980,ABC_FLAG_ID=1281791
# 4                                                                     NaN
# ..                                                                    ...
# 107     DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=207026,ABC_FLAG_ID=1281836
# 108                                                                   NaN
# 109       DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=226792,ABC_FLAG_ID=1281813
# 110                                                                   NaN
# 111  DEVICE=*,LAYER=8ZRO_FTL_PREGOOP,OPERATION=202264,ABC_FLAG_ID=1281639
#
#     data_last_update_abc
# 0             08/08/2025
# 1             08/08/2025
# 2                    NaN
# 3             08/08/2025
# 4                    NaN
# ..                   ...
# 107           08/08/2025
# 108                  NaN
# 109           08/08/2025
# 110                  NaN
# 111           08/08/2025
#
# [112 rows x 9 columns]

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

swish.merge(
    abc,
    on=['entity', 'fab', 'FLAG_ID'],
    how='inner'
)
# Out:
#          entity  feed_value_swish  \
# 0     DVD01_PM2          0.255749
# 1        EPF531          0.234640
# 2        LEO431          0.213549
# 3        DRT422          0.542788
# 4        CDT448          0.542788
# 5        FOX428          0.253004
# 6   ABV424_DCM1          0.689385
# 7        NST412          0.799450
# 8        OMG505          0.805175
# 9        SAF533          0.793921
# 10       NST510          0.228752
# 11   APT401_PM1          0.475122
# 12   GTT476_PM1          0.317809
# 13  CDT488_DCM1          0.471916
# 14       TBE406          0.459195
# 15       FOX406          0.467007
# 16       FOX408          0.209424
# 17       ALE436          0.227334
# 18       FTL402          0.293627
# 19       OMG504          0.423904
# 20       SAF532          0.321054
# 21       SPK412          0.085379
# 22       NCD406          0.125119
# 23       PGX402          0.230223
# 24       FTL414          0.216919
# 25       BPQ418          0.588021
# 26   GTT448_PM5          0.119654
# 27       APT440          0.245376
# 28   GTT588_PM2          0.451054
# 29   APT440_PM2          0.254270
# 30   APT440_PM3          0.185177
# 31   APT440_PM1          0.204634
# 32   GTA404_PM5          0.175589
# 33       CVD417          0.390605
#
#                                                 details_swish  \
# 0   PROCESS=1278,ABC_FLAG_IDS=[1281769],OPERATIONS=['258018']
# 1   PROCESS=1278,ABC_FLAG_IDS=[1281770],OPERATIONS=['261415']
# 2   PROCESS=1278,ABC_FLAG_IDS=[1281771],OPERATIONS=['243221']
# 3   PROCESS=1278,ABC_FLAG_IDS=[1281798],OPERATIONS=['205090']
# 4   PROCESS=1278,ABC_FLAG_IDS=[1281799],OPERATIONS=['205074']
# 5   PROCESS=1278,ABC_FLAG_IDS=[1281800],OPERATIONS=['205122']
# 6   PROCESS=1278,ABC_FLAG_IDS=[1281801],OPERATIONS=['205632']
# 7   PROCESS=1278,ABC_FLAG_IDS=[1281802],OPERATIONS=['225704']
# 8   PROCESS=1278,ABC_FLAG_IDS=[1281803],OPERATIONS=['242933']
# 9   PROCESS=1278,ABC_FLAG_IDS=[1281804],OPERATIONS=['242990']
# 10  PROCESS=1278,ABC_FLAG_IDS=[1281809],OPERATIONS=['225401']
# 11  PROCESS=1278,ABC_FLAG_IDS=[1281810],OPERATIONS=['225083']
# 12  PROCESS=1278,ABC_FLAG_IDS=[1281811],OPERATIONS=['247751']
# 13  PROCESS=1278,ABC_FLAG_IDS=[1281812],OPERATIONS=['226440']
# 14  PROCESS=1278,ABC_FLAG_IDS=[1281813],OPERATIONS=['226792']
# 15  PROCESS=1278,ABC_FLAG_IDS=[1281814],OPERATIONS=['225210']
# 16  PROCESS=1278,ABC_FLAG_IDS=[1281815],OPERATIONS=['225210']
# 17  PROCESS=1278,ABC_FLAG_IDS=[1281816],OPERATIONS=['258704']
# 18  PROCESS=1278,ABC_FLAG_IDS=[1281817],OPERATIONS=['214155']
# 19  PROCESS=1278,ABC_FLAG_IDS=[1281818],OPERATIONS=['242939']
# 20  PROCESS=1278,ABC_FLAG_IDS=[1281819],OPERATIONS=['258365']
# 21  PROCESS=1278,ABC_FLAG_IDS=[1281836],OPERATIONS=['207026']
# 22  PROCESS=1278,ABC_FLAG_IDS=[1281837],OPERATIONS=['254145']
# 23  PROCESS=1278,ABC_FLAG_IDS=[1281838],OPERATIONS=['251263']
# 24  PROCESS=1278,ABC_FLAG_IDS=[1281839],OPERATIONS=['214155']
# 25  PROCESS=1278,ABC_FLAG_IDS=[1281840],OPERATIONS=['143803']
# 26  PROCESS=1278,ABC_FLAG_IDS=[1281868],OPERATIONS=['245040']
# 27  PROCESS=1278,ABC_FLAG_IDS=[1281869],OPERATIONS=['254454']
# 28  PROCESS=1278,ABC_FLAG_IDS=[1281901],OPERATIONS=['245041']
# 29  PROCESS=1278,ABC_FLAG_IDS=[1281902],OPERATIONS=['240261']
# 30  PROCESS=1278,ABC_FLAG_IDS=[1281903],OPERATIONS=['240261']
# 31  PROCESS=1278,ABC_FLAG_IDS=[1281904],OPERATIONS=['240261']
# 32  PROCESS=1278,ABC_FLAG_IDS=[1281905],OPERATIONS=['254617']
# 33  PROCESS=1278,ABC_FLAG_IDS=[1281906],OPERATIONS=['212825']
#
#    data_last_update_swish  fab  FLAG_ID  feed_value_abc  \
# 0              08/07/2025  D1D  1281769        0.984687
# 1              08/06/2025  D1D  1281770        0.678500
# 2              08/06/2025  D1D  1281771        0.758623
# 3              08/08/2025  D1D  1281798        0.858923
# 4              08/08/2025  D1D  1281799        0.947032
# 5              08/08/2025  D1D  1281800        0.993602
# 6              08/08/2025  D1D  1281801        0.915279
# 7              08/08/2025  D1D  1281802        0.986337
# 8              08/08/2025  D1D  1281803        0.977704
# 9              08/08/2025  D1D  1281804        0.999778
# 10             08/08/2025  D1D  1281809        0.692985
# 11             08/07/2025  D1D  1281810        0.565242
# 12             08/08/2025  D1D  1281811        0.753253
# 13             08/06/2025  D1D  1281812        0.561233
# 14             08/05/2025  D1D  1281813        0.870863
# 15             08/06/2025  D1D  1281814        0.979494
# 16             08/07/2025  D1D  1281815        0.811398
# 17             08/07/2025  D1D  1281816        0.574977
# 18             08/07/2025  D1D  1281817        0.999995
# 19             08/06/2025  D1D  1281818        0.888045
# 20             08/07/2025  D1D  1281819        0.855995
# 21             08/08/2025  D1D  1281836        0.978923
# 22             08/08/2025  D1D  1281837        0.989080
# 23             08/08/2025  D1D  1281838        0.994446
# 24             08/08/2025  D1D  1281839        0.999627
# 25             08/07/2025  D1D  1281840        0.648215
# 26             08/08/2025  D1D  1281868        0.730354
# 27             08/07/2025  D1D  1281869        0.919374
# 28             08/05/2025  D1D  1281901        0.679347
# 29             08/04/2025  D1D  1281902        0.976454
# 30             08/04/2025  D1D  1281903        0.939870
# 31             08/04/2025  D1D  1281904        0.939870
# 32             08/07/2025  D1D  1281905        1.000000
# 33             08/05/2025  D1D  1281906        0.688425
#
#                                                           details_abc  \
# 0        DEVICE=*,LAYER=8TRM_FTL,OPERATION=258018,ABC_FLAG_ID=1281769
# 1        DEVICE=*,LAYER=8TRM_FTL,OPERATION=261415,ABC_FLAG_ID=1281770
# 2        DEVICE=*,LAYER=8TRM_FTL,OPERATION=243221,ABC_FLAG_ID=1281771
# 3        DEVICE=*,LAYER=8HNS_FTL,OPERATION=205090,ABC_FLAG_ID=1281798
# 4        DEVICE=*,LAYER=8HNS_FTL,OPERATION=205074,ABC_FLAG_ID=1281799
# 5        DEVICE=*,LAYER=8HNS_FTL,OPERATION=205122,ABC_FLAG_ID=1281800
# 6        DEVICE=*,LAYER=8HNS_FTL,OPERATION=205632,ABC_FLAG_ID=1281801
# 7        DEVICE=*,LAYER=8HNS_FTL,OPERATION=225704,ABC_FLAG_ID=1281802
# 8        DEVICE=*,LAYER=8HNS_FTL,OPERATION=242933,ABC_FLAG_ID=1281803
# 9        DEVICE=*,LAYER=8HNS_FTL,OPERATION=242990,ABC_FLAG_ID=1281804
# 10    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=225401,ABC_FLAG_ID=1281809
# 11    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=225083,ABC_FLAG_ID=1281810
# 12    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=247751,ABC_FLAG_ID=1281811
# 13    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=226440,ABC_FLAG_ID=1281812
# 14    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=226792,ABC_FLAG_ID=1281813
# 15    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=225210,ABC_FLAG_ID=1281814
# 16    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=225210,ABC_FLAG_ID=1281815
# 17    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=258704,ABC_FLAG_ID=1281816
# 18    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=214155,ABC_FLAG_ID=1281817
# 19    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=242939,ABC_FLAG_ID=1281818
# 20    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=258365,ABC_FLAG_ID=1281819
# 21  DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=207026,ABC_FLAG_ID=1281836
# 22  DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=254145,ABC_FLAG_ID=1281837
# 23  DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=251263,ABC_FLAG_ID=1281838
# 24  DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=214155,ABC_FLAG_ID=1281839
# 25  DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=143803,ABC_FLAG_ID=1281840
# 26    DEVICE=*,LAYER=8VCXPOL_FTL,OPERATION=245040,ABC_FLAG_ID=1281868
# 27    DEVICE=*,LAYER=8VCXPOL_FTL,OPERATION=254454,ABC_FLAG_ID=1281869
# 28       DEVICE=*,LAYER=8VCG_FTL,OPERATION=245041,ABC_FLAG_ID=1281901
# 29       DEVICE=*,LAYER=8VCG_FTL,OPERATION=240261,ABC_FLAG_ID=1281902
# 30       DEVICE=*,LAYER=8VCG_FTL,OPERATION=240261,ABC_FLAG_ID=1281903
# 31       DEVICE=*,LAYER=8VCG_FTL,OPERATION=240261,ABC_FLAG_ID=1281904
# 32       DEVICE=*,LAYER=8VCG_FTL,OPERATION=254617,ABC_FLAG_ID=1281905
# 33       DEVICE=*,LAYER=8VCG_FTL,OPERATION=212825,ABC_FLAG_ID=1281906
#
#    data_last_update_abc
# 0            08/08/2025
# 1            08/08/2025
# 2            08/08/2025
# 3            08/08/2025
# 4            08/08/2025
# 5            08/08/2025
# 6            08/08/2025
# 7            08/08/2025
# 8            08/08/2025
# 9            08/08/2025
# 10           08/08/2025
# 11           08/08/2025
# 12           08/08/2025
# 13           08/08/2025
# 14           08/08/2025
# 15           08/08/2025
# 16           08/08/2025
# 17           08/08/2025
# 18           08/08/2025
# 19           08/08/2025
# 20           08/08/2025
# 21           08/08/2025
# 22           08/08/2025
# 23           08/08/2025
# 24           08/08/2025
# 25           08/08/2025
# 26           08/08/2025
# 27           08/08/2025
# 28           08/08/2025
# 29           08/08/2025
# 30           08/08/2025
# 31           08/08/2025
# 32           08/08/2025
# 33           08/08/2025

# %%
# FLAG_ID_join.to_csv('FLAG_ID_join_output.csv', index=False)

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

FLAG_ID_inner_join = swish.merge(
    abc,
    on=['FLAG_ID', 'entity', 'fab'],
    how='inner'
)
FLAG_ID_inner_join.head()
# FLAG_ID_join.to_csv('FLAG_ID_entity_fab_outer_join.csv', index=False)
# Out:
#       entity  feed_value_swish  \
# 0  DVD01_PM2          0.255749
# 1     EPF531          0.234640
# 2     LEO431          0.213549
# 3     DRT422          0.542788
# 4     CDT448          0.542788
#
#                                                details_swish  \
# 0  PROCESS=1278,ABC_FLAG_IDS=[1281769],OPERATIONS=['258018']
# 1  PROCESS=1278,ABC_FLAG_IDS=[1281770],OPERATIONS=['261415']
# 2  PROCESS=1278,ABC_FLAG_IDS=[1281771],OPERATIONS=['243221']
# 3  PROCESS=1278,ABC_FLAG_IDS=[1281798],OPERATIONS=['205090']
# 4  PROCESS=1278,ABC_FLAG_IDS=[1281799],OPERATIONS=['205074']
#
#   data_last_update_swish  fab  FLAG_ID  feed_value_abc  \
# 0             08/07/2025  D1D  1281769        0.984687
# 1             08/06/2025  D1D  1281770        0.678500
# 2             08/06/2025  D1D  1281771        0.758623
# 3             08/08/2025  D1D  1281798        0.858923
# 4             08/08/2025  D1D  1281799        0.947032
#
#                                                     details_abc  \
# 0  DEVICE=*,LAYER=8TRM_FTL,OPERATION=258018,ABC_FLAG_ID=1281769
# 1  DEVICE=*,LAYER=8TRM_FTL,OPERATION=261415,ABC_FLAG_ID=1281770
# 2  DEVICE=*,LAYER=8TRM_FTL,OPERATION=243221,ABC_FLAG_ID=1281771
# 3  DEVICE=*,LAYER=8HNS_FTL,OPERATION=205090,ABC_FLAG_ID=1281798
# 4  DEVICE=*,LAYER=8HNS_FTL,OPERATION=205074,ABC_FLAG_ID=1281799
#
#   data_last_update_abc
# 0           08/08/2025
# 1           08/08/2025
# 2           08/08/2025
# 3           08/08/2025
# 4           08/08/2025

# %%
FLAG_ID_inner_join['feed_value_diff'] = FLAG_ID_inner_join['feed_value_abc'] - FLAG_ID_inner_join['feed_value_swish']
FLAG_ID_inner_join.head()
# Out:
#       entity  feed_value_swish  \
# 0  DVD01_PM2          0.255749
# 1     EPF531          0.234640
# 2     LEO431          0.213549
# 3     DRT422          0.542788
# 4     CDT448          0.542788
#
#                                                details_swish  \
# 0  PROCESS=1278,ABC_FLAG_IDS=[1281769],OPERATIONS=['258018']
# 1  PROCESS=1278,ABC_FLAG_IDS=[1281770],OPERATIONS=['261415']
# 2  PROCESS=1278,ABC_FLAG_IDS=[1281771],OPERATIONS=['243221']
# 3  PROCESS=1278,ABC_FLAG_IDS=[1281798],OPERATIONS=['205090']
# 4  PROCESS=1278,ABC_FLAG_IDS=[1281799],OPERATIONS=['205074']
#
#   data_last_update_swish  fab  FLAG_ID  feed_value_abc  \
# 0             08/07/2025  D1D  1281769        0.984687
# 1             08/06/2025  D1D  1281770        0.678500
# 2             08/06/2025  D1D  1281771        0.758623
# 3             08/08/2025  D1D  1281798        0.858923
# 4             08/08/2025  D1D  1281799        0.947032
#
#                                                     details_abc  \
# 0  DEVICE=*,LAYER=8TRM_FTL,OPERATION=258018,ABC_FLAG_ID=1281769
# 1  DEVICE=*,LAYER=8TRM_FTL,OPERATION=261415,ABC_FLAG_ID=1281770
# 2  DEVICE=*,LAYER=8TRM_FTL,OPERATION=243221,ABC_FLAG_ID=1281771
# 3  DEVICE=*,LAYER=8HNS_FTL,OPERATION=205090,ABC_FLAG_ID=1281798
# 4  DEVICE=*,LAYER=8HNS_FTL,OPERATION=205074,ABC_FLAG_ID=1281799
#
#   data_last_update_abc  feed_value_diff
# 0           08/08/2025         0.728938
# 1           08/08/2025         0.443860
# 2           08/08/2025         0.545074
# 3           08/08/2025         0.316135
# 4           08/08/2025         0.404244

# %%
#Sort the df by 'feed_value_diff' in ascendingo rder 
inner_join_sorted = FLAG_ID_inner_join.sort_values(by='feed_value_diff', ascending=True)
inner_join_sorted.head()
# Out:
#          entity  feed_value_swish  \
# 25       BPQ418          0.588021
# 13  CDT488_DCM1          0.471916
# 11   APT401_PM1          0.475122
# 8        OMG505          0.805175
# 7        NST412          0.799450
#
#                                                 details_swish  \
# 25  PROCESS=1278,ABC_FLAG_IDS=[1281840],OPERATIONS=['143803']
# 13  PROCESS=1278,ABC_FLAG_IDS=[1281812],OPERATIONS=['226440']
# 11  PROCESS=1278,ABC_FLAG_IDS=[1281810],OPERATIONS=['225083']
# 8   PROCESS=1278,ABC_FLAG_IDS=[1281803],OPERATIONS=['242933']
# 7   PROCESS=1278,ABC_FLAG_IDS=[1281802],OPERATIONS=['225704']
#
#    data_last_update_swish  fab  FLAG_ID  feed_value_abc  \
# 25             08/07/2025  D1D  1281840        0.648215
# 13             08/06/2025  D1D  1281812        0.561233
# 11             08/07/2025  D1D  1281810        0.565242
# 8              08/08/2025  D1D  1281803        0.977704
# 7              08/08/2025  D1D  1281802        0.986337
#
#                                                           details_abc  \
# 25  DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=143803,ABC_FLAG_ID=1281840
# 13    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=226440,ABC_FLAG_ID=1281812
# 11    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=225083,ABC_FLAG_ID=1281810
# 8        DEVICE=*,LAYER=8HNS_FTL,OPERATION=242933,ABC_FLAG_ID=1281803
# 7        DEVICE=*,LAYER=8HNS_FTL,OPERATION=225704,ABC_FLAG_ID=1281802
#
#    data_last_update_abc  feed_value_diff
# 25           08/08/2025         0.060194
# 13           08/08/2025         0.089317
# 11           08/08/2025         0.090120
# 8            08/08/2025         0.172529
# 7            08/08/2025         0.186887

# %%
df = inner_join_sorted[[
    'entity',
    'fab',
    'FLAG_ID',
    'data_last_update_swish',
    'data_last_update_abc',
    'details_swish',
    'details_abc',
    'feed_value_swish',
    'feed_value_abc',
    'feed_value_diff'
]]
df.head()
# Out:
#          entity  fab  FLAG_ID data_last_update_swish data_last_update_abc  \
# 25       BPQ418  D1D  1281840             08/07/2025           08/08/2025
# 13  CDT488_DCM1  D1D  1281812             08/06/2025           08/08/2025
# 11   APT401_PM1  D1D  1281810             08/07/2025           08/08/2025
# 8        OMG505  D1D  1281803             08/08/2025           08/08/2025
# 7        NST412  D1D  1281802             08/08/2025           08/08/2025
#
#                                                 details_swish  \
# 25  PROCESS=1278,ABC_FLAG_IDS=[1281840],OPERATIONS=['143803']
# 13  PROCESS=1278,ABC_FLAG_IDS=[1281812],OPERATIONS=['226440']
# 11  PROCESS=1278,ABC_FLAG_IDS=[1281810],OPERATIONS=['225083']
# 8   PROCESS=1278,ABC_FLAG_IDS=[1281803],OPERATIONS=['242933']
# 7   PROCESS=1278,ABC_FLAG_IDS=[1281802],OPERATIONS=['225704']
#
#                                                           details_abc  \
# 25  DEVICE=*,LAYER=8STLTREM1_FTL,OPERATION=143803,ABC_FLAG_ID=1281840
# 13    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=226440,ABC_FLAG_ID=1281812
# 11    DEVICE=*,LAYER=8DR6TLE_FTL,OPERATION=225083,ABC_FLAG_ID=1281810
# 8        DEVICE=*,LAYER=8HNS_FTL,OPERATION=242933,ABC_FLAG_ID=1281803
# 7        DEVICE=*,LAYER=8HNS_FTL,OPERATION=225704,ABC_FLAG_ID=1281802
#
#     feed_value_swish  feed_value_abc  feed_value_diff
# 25          0.588021        0.648215         0.060194
# 13          0.471916        0.561233         0.089317
# 11          0.475122        0.565242         0.090120
# 8           0.805175        0.977704         0.172529
# 7           0.799450        0.986337         0.186887

# %%
df.to_csv('Reordered_inner_join.csv', index=False)

# %%
df['feed_value_swish'].min(), df['feed_value_swish'].max()
# Out:
# (np.float64(0.085379), np.float64(0.805175))

# %%
df['feed_value_abc'].min(), df['feed_value_abc'].max()
# Out:
# (np.float64(0.5612326651638393), np.float64(0.9999999600716786))

# %%
import matplotlib.pyplot as plt

# %%
df.index
# Out:
# Index([25, 13, 11,  8,  7,  9,  6, 28, 33,  3, 17,  4, 14, 12,  1, 19, 10, 15,
#        20,  2, 16, 26, 27, 18, 29,  0, 31,  5, 30, 23, 24, 32, 22, 21],
#       dtype='int64')

# %%
x = range(1, len(df)+1)

# %%
plt.plot(x, df['feed_value_swish'], label='Swish Feed')

# %%
plt.plot(x, df['feed_value_abc'], label='ABC Feed')

# %%
plt.plot(x, df['feed_value_diff'], label='Feed Value Difference')

# %%
plt.figure(figsize=(12,6))
plt.plot(x, df['feed_value_abc'], label='ABC Feed')
plt.plot(x, df['feed_value_swish'], label='Swish Feed')
plt.plot(x, df['feed_value_diff'], label='Feed Value Difference')

plt.xlabel('Number of Flagged Entities (Ordered by Feed Value Difference)')
plt.ylabel('Feed Value')
plt.title('Overlay of Feed Values')
plt.legend(loc ='upper left', bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(x, df['feed_value_abc'], label='ABC Feed')
plt.scatter(x, df['feed_value_abc'], color='blue', s=40, marker='o')

plt.plot(x, df['feed_value_swish'], label='Swish Feed')
plt.scatter(x, df['feed_value_swish'], color='orange', s=40, marker='o')

plt.plot(x, df['feed_value_diff'], label='Feed Value Difference')
plt.scatter(x, df['feed_value_diff'], color='green', s=40, marker='o')

plt.xlabel('Number of Flagged Entities (Ordered by Feed Value Difference)')
plt.ylabel('Feed Value')
plt.title('Overlay of Feed Values')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %%
plt.hist(df['feed_value_swish'], bins=9, alpha=0.5, label='Swish Feed', color='blue')
plt.hist(df['feed_value_abc'], alpha=0.5, bins=9, label='ABC Feed', color='orange')
plt.hist(df['feed_value_diff'], alpha=0.5, bins=9, label='Feed Difference', color='green')
# Out:
# (array([3., 5., 2., 3., 5., 4., 2., 7., 3.]),
#  array([0.06019432, 0.1527887 , 0.24538308, 0.33797746, 0.43057184,
#         0.52316623, 0.61576061, 0.70835499, 0.80094937, 0.89354375]),
#  <BarContainer object of 9 artists>)

# %%
df['feed_value_swish'].plot(kind='kde', label='Swish Feed', color='blue')
df['feed_value_abc'].plot(kind='kde', label='ABC Feed', color='orange')
# Out:
# <Axes: ylabel='Density'>

# %%
ax = df['feed_value_swish'].plot(kind='kde', label='Swish Feed', color='blue')
df['feed_value_abc'].plot(kind='kde', label='ABC Feed', color='orange', ax=ax)

#Filling the area under the curves
x_swish = ax.get_lines()[0].get_xdata() 
y_swish = ax.get_lines()[0].get_ydata()
ax.fill_between(x_swish, y_swish, color='blue', alpha=0.3)

x_abc = ax.get_lines()[1].get_xdata()
y_abc = ax.get_lines()[1].get_ydata()
ax.fill_between(x_abc, y_abc, color='orange', alpha=0.3)

plt.xlabel('Feed Value')
plt.ylabel('Density')
# plt.title('Kernel Density Estimate: Swish Feed vs ABC Feed (Filled)')
plt.title('Relative Distribution of Feed Values: Swish vs ABC')

plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
# Histogram
plt.hist(df['feed_value_swish'], bins=30, alpha=0.4, label='Swish Feed', color='blue', density=True)
plt.hist(df['feed_value_abc'], bins=30, alpha=0.4, label='ABC Feed', color='orange', density=True)
# KDE
df['feed_value_swish'].plot(kind='kde', label='Swish Feed KDE', color='blue')
df['feed_value_abc'].plot(kind='kde', label='ABC Feed KDE', color='orange')

plt.xlabel('Feed Value')
plt.ylabel('Density')
plt.title('Histogram and KDE Overlay: Swish Feed vs ABC Feed')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
